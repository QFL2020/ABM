# %% [markdown]
# ## Create weight matrix to represent proximity between regions

# %%
import requests
import numpy as np
import pandas as pd
import pickle

# %%
# input
with open('country_iata.pkl','rb') as f:
    iata=pickle.load(f)
    
exclude=['Liechtenstein', 'San Marino','Andorra','West Bank and Gaza','Burma']
for k in exclude:
    if k in iata.keys():
        del iata[k]

# %%
# flight hours

z={}
for i in range(158):
    with open('flight_hrs_4/country_'+str(i)+'.pkl','rb') as f:
        x=pickle.load(f)
    z.update(x)
    
exclude=['Liechtenstein', 'San Marino','Andorra','West Bank and Gaza','Burma']
for k in exclude:
    if k in z.keys():
        del z[k]

# %%
airports=pd.read_csv("airports.csv")
#airports.dropna(subset=['iata_code']).to_csv("airports.csv",index=False)

# %% [markdown]
# ## correction

# %% [markdown]
# ### 1. fill in missing data

# %%
# missing data

# check the number of missing entries per country
n={i:0 for i in z}
for i in n:
    for k in z[i]:
        if z[i][k]==10**6: # missing entry 
            n[i]+=1
for i in n:
    if n[i]>10:
        print(i,iata[i],n[i])
# Out:
# Cuba ['CFG'] 157
# Monaco ['MCM'] 157

# %% [markdown]
# ###  replace missing data with data from nearest neighbor
# - find coordinates for countries, proxy by the location of the airport of their capitals
# - use neighbor hours as proxy
#         - find the closest neighbor with data available

# %%
airports=pd.read_csv("airports.csv")

# coordinates for countries
location={i:0 for i in iata}
df={'country':[],'latitude':[],'longitude':[]}

for i in location:
    loc=np.zeros(2)
    nport=len(iata[i])
    for j in iata[i]:
        cond=(airports.iata_code==j) #& (airports.scheduled_service=='yes')
        if cond.sum()>1:
            cond = cond & (airports.type!='closed')
        if cond.sum()>1:
            cond = cond & (airports.scheduled_service=='yes')
        if cond.sum()>1:
            print(i,j,airports[cond].latitude_deg.to_numpy(),airports[cond].longitude_deg.to_numpy())
            print()
        lat=airports[cond].iloc[-1].latitude_deg.item()
        long=airports[cond].iloc[-1].longitude_deg.item()
        loc[0]+=lat/nport
        loc[1]+=long/nport
    #location[i]=loc
    df['country'].append(i)
    df['latitude'].append(loc[0])
    df['longitude'].append(loc[1])

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#                  country   latitude  longitude
# 0            Afghanistan  34.565899  69.212303
# 1                Albania  41.414700  19.720600
# 2                Algeria  36.691002   3.215410
# 3                 Angola  -8.858370  13.231200
# 4    Antigua and Barbuda  17.136700 -61.792702
# ..                   ...        ...        ...
# 152           Uzbekistan  41.257900  69.281197
# 153            Venezuela  10.601194 -66.991222
# 154               Zambia -15.330800  28.452600
# 155             Zimbabwe -17.931801  31.092800
# 156                   US  39.311034 -78.261233
#
# [157 rows x 3 columns]

# %%
#df.to_csv("country_coordinates.csv")

# %%
# init weight matrix
countries=location.keys()
weight={}
for c in countries:
    weight[c]={}

# %%
# rank neighbors by by distance
neighbors={c:{'name':[],'dist':[]} for c in countries}
def distance(a,b):
    a=location[a]
    b=location[b]
    return ((a-b)**2).sum()

for c in countries:
    for c2 in countries:
        if c==c2: continue
        neighbors[c]['name'].append(c2)
        neighbors[c]['dist'].append(distance(c,c2))
    neighbors[c]=[x for _, x in sorted(zip(neighbors[c]['dist'], neighbors[c]['name']))]

# %%
neighbors['Cuba']
# Out:
# ['Bahamas',
#  'Jamaica',
#  'Haiti',
#  'Belize',
#  'Honduras',
#  'Dominican Republic',
#  'Nicaragua',
#  'El Salvador',
#  'Guatemala',
#  'Costa Rica',
#  'Panama',
#  'US',
#  'Venezuela',
#  'Colombia',
#  'Mexico',
#  'Antigua and Barbuda',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Trinidad and Tobago',
#  'Ecuador',
#  'Barbados',
#  'Canada',
#  'Guyana',
#  'Suriname',
#  'Peru',
#  'Bolivia',
#  'Brazil',
#  'Paraguay',
#  'Chile',
#  'Cabo Verde',
#  'Argentina',
#  'Uruguay',
#  'Senegal',
#  'Gambia',
#  'Mauritania',
#  'Guinea-Bissau',
#  'Guinea',
#  'Iceland',
#  'Mali',
#  'Portugal',
#  'Morocco',
#  "Cote d'Ivoire",
#  'Spain',
#  'Burkina Faso',
#  'Ireland',
#  'Ghana',
#  'Togo',
#  'Algeria',
#  'United Kingdom',
#  'France',
#  'Nigeria',
#  'Belgium',
#  'Sao Tome and Principe',
#  'Netherlands',
#  'Monaco',
#  'Luxembourg',
#  'Equatorial Guinea',
#  'Switzerland',
#  'Tunisia',
#  'Gabon',
#  'Cameroon',
#  'Libya',
#  'Italy',
#  'Malta',
#  'Slovenia',
#  'Germany',
#  'Angola',
#  'Denmark',
#  'Czechia',
#  'Norway',
#  'Congo (Brazzaville)',
#  'Croatia',
#  'Congo (Kinshasa)',
#  'Austria',
#  'Central African Republic',
#  'Slovakia',
#  'Bosnia and Herzegovina',
#  'Montenegro',
#  'Albania',
#  'Hungary',
#  'Serbia',
#  'Kosovo',
#  'North Macedonia',
#  'Sweden',
#  'Greece',
#  'Poland',
#  'Bulgaria',
#  'Namibia',
#  'Romania',
#  'Latvia',
#  'Lithuania',
#  'Estonia',
#  'Finland',
#  'Egypt',
#  'Moldova',
#  'Belarus',
#  'Rwanda',
#  'Sudan',
#  'South Sudan',
#  'Ukraine',
#  'Cyprus',
#  'Turkey',
#  'Uganda',
#  'Zambia',
#  'Israel',
#  'Botswana',
#  'Lebanon',
#  'Jordan',
#  'Syria',
#  'Zimbabwe',
#  'South Africa',
#  'Kenya',
#  'Lesotho',
#  'Malawi',
#  'Ethiopia',
#  'Eswatini',
#  'Mozambique',
#  'Russia',
#  'Djibouti',
#  'Iraq',
#  'Armenia',
#  'Georgia',
#  'Saudi Arabia',
#  'Somalia',
#  'Comoros',
#  'Kuwait',
#  'Bahrain',
#  'Azerbaijan',
#  'Qatar',
#  'Iran',
#  'Madagascar',
#  'United Arab Emirates',
#  'Seychelles',
#  'Oman',
#  'Tajikistan',
#  'Afghanistan',
#  'Uzbekistan',
#  'Pakistan',
#  'Kazakhstan',
#  'Maldives',
#  'Kyrgyzstan',
#  'India',
#  'Sri Lanka',
#  'Nepal',
#  'Bangladesh',
#  'Thailand',
#  'Malaysia',
#  'Singapore',
#  'Mongolia',
#  'Indonesia',
#  'China',
#  'Philippines',
#  'Korea, South',
#  'Japan',
#  'Papua New Guinea',
#  'Australia']

# %%
def get_weight(c,c2):        
    ''' 
    get the weiight between c and c2
    - if flight_hours[c][c2] exist, return
    - find nearest neighbor(s) with data available '''
    
    if c==c2: return 0,0
    if (c2 in z[c]) and z[c][c2]<10**6:
        return z[c][c2]
    else: # no flight from c2 to c
        # look for neighbors of c
        # and neighbors of c2
        
        dist=[]
        step=[]
        step_penalty=0.5
        print(c,c2)
        for i in range(len(neighbors[c])):
            c_i=neighbors[c][i]
            # replace c by its neighbor
            if not (c_i==c2) and z[c_i][c2]<10**6:
                
                dist.append(z[c_i][c2])
                step.append(i+step_penalty)
                break
            c_i=neighbors[c2][i]
            # replace c2 by its neighbor
            if not (c_i==c) and z[c][c_i]<10**6:

                dist.append(z[c][c_i])
                step.append(i+step_penalty)
                break
        # replace both c and c2 by their neighbors
        for i in range(len(neighbors[c])):
            c_i=neighbors[c][i]
            for j in range(len(neighbors[c])):
                c_j=neighbors[c2][j]
                if not (c_i==c_j) and z[c_i][c_j]<10**6:
                    dist.append(z[c_i][c_j])
                    step.append(i+j+step_penalty*2)
                    break
        min_step=min(step)
        min_i=step.index(min_step)
        print('steps',min_step)
        return dist[min_i]+min_step

# %%
get_weight('Eswatini','Australia')
# Out:
# 27.58

# %%
get_weight('Eswatini','Papua New Guinea')
# Out:
# 33.25

# %%
get_weight('Australia','Papua New Guinea')
# Out:
# 7.08

# %%
get_weight('Papua New Guinea','Australia')
# Out:
# 7.58

# %%
c=''
for i in neighbors[c]:
    print(i,get_weight(i,c))
    print()
# Out:
# Australia 7.08
#
# Philippines 5.33
#
# Indonesia 17.17
#
# Singapore 6.5
#
# Japan 24.83
#
# Malaysia 19.67
#
# Korea, South 25.33
#
# Thailand 25.17
#
# China 19.58
#
# Bangladesh 22.0
#
# Sri Lanka 20.58
#
# Mongolia 26.17
#
# Nepal 29.25
#
# Maldives 27.67
#
# India 27.67
#
# Pakistan 36.83
#
# Afghanistan 33.17
#
# Kyrgyzstan 29.17
#
# Seychelles 25.67
#
# Tajikistan 35.25
#
# Uzbekistan 28.83
#
# Oman 29.83
#
# Kazakhstan 30.67
#
# United Arab Emirates 29.0
#
# Madagascar 39.92
#
# Qatar 23.83
#
# Somalia 29.42
#
# Bahrain 32.92
#
# Comoros 36.83
#
# Iran 31.08
#
# Djibouti 26.17
#
# Saudi Arabia 34.67
#
# Kuwait 34.75
#
# Azerbaijan 24.17
#
# Ethiopia 44.67
#
# Kenya 34.25
#
# Iraq 30.0
#
# Malawi 44.17
#
# Armenia 25.58
#
# Georgia 33.42
#
# Uganda 28.58
#
# Mozambique 32.92
#
# Zimbabwe 32.17
#
# South Sudan 30.58
#
# Eswatini 33.25
#
# Rwanda 33.67
#
# Sudan 25.17
#
# Jordan 25.33
#
# Syria 47.33
#
# Zambia 29.25
#
# Israel 24.33
#
# Lebanon 30.75
#
# South Africa 31.5
#
# Lesotho 33.08
#
# Cyprus 30.33
#
# Botswana 32.67
#
# Egypt 47.33
#
# Turkey 33.83
#
# Russia 30.08
#
# Central African Republic 41.5
#
# Namibia 38.17
#
# Moldova 31.67
#
# Ukraine 32.92
#
# Congo (Kinshasa) 36.58
#
# Congo (Brazzaville) 36.17
#
# Greece 34.08
#
# Romania 58.0
#
# Angola 28.75
#
# Bulgaria 37.92
#
# Belarus 53.67
#
# North Macedonia 34.42
#
# Cameroon 37.67
#
# Kosovo 34.75
#
# Albania 35.92
#
# Lithuania 38.67
#
# Serbia 34.5
#
# Montenegro 30.83
#
# Gabon 39.0
#
# Equatorial Guinea 36.67
#
# Bosnia and Herzegovina 31.42
#
# Latvia 37.83
#
# Hungary 40.0
#
# Malta 45.08
#
# Estonia 36.5
#
# Libya 32.17
#
# Poland 29.42
#
# Finland 34.0
#
# Sao Tome and Principe 34.5
#
# Nigeria 31.08
#
# Slovakia 28.83
#
# Croatia 54.75
#
# Austria 49.25
#
# Slovenia 36.75
#
# Italy 36.0
#
# Tunisia 37.75
#
# Czechia 40.67
#
# Sweden 31.92
#
# Togo 38.42
#
# Germany 34.5
#
# Ghana 28.25
#
# Monaco Papua New Guinea
# steps 0.5
# Monaco 34.25
#
# Denmark 32.58
#
# Burkina Faso 34.25
#
# Switzerland 33.75
#
# Algeria 39.0
#
# Cote d'Ivoire 31.0
#
# Luxembourg 45.42
#
# Norway 43.42
#
# Belgium 33.25
#
# Netherlands 52.42
#
# France 32.92
#
# Mali 37.33
#
# Spain 54.5
#
# United Kingdom 29.58
#
# Morocco 35.08
#
# Guinea 37.17
#
# Portugal 55.17
#
# Guinea-Bissau 38.08
#
# Gambia 36.33
#
# Mauritania 39.42
#
# Ireland 37.08
#
# Senegal 35.92
#
# Cabo Verde 41.25
#
# Iceland 39.67
#
# Brazil 41.17
#
# Suriname 45.33
#
# Uruguay 38.3
#
# Paraguay 39.75
#
# Guyana 41.58
#
# Argentina 37.08
#
# Barbados 37.42
#
# Trinidad and Tobago 41.32
#
# Saint Lucia 37.55
#
# Saint Vincent and the Grenadines 42.58
#
# Antigua and Barbuda 38.73
#
# Venezuela 40.3
#
# Bolivia 43.4
#
# Dominican Republic 33.08
#
# Chile 34.58
#
# Haiti 36.98
#
# Colombia 33.12
#
# Peru 35.67
#
# Jamaica 37.42
#
# Ecuador 35.75
#
# Bahamas 36.33
#
# Panama 35.12
#
# Canada 34.2
#
# Cuba Papua New Guinea
# steps 0.5
# Cuba 36.83
#
# US 28.05
#
# Costa Rica 33.18
#
# Nicaragua 39.08
#
# Honduras 36.73
#
# Belize 33.4
#
# El Salvador 32.83
#
# Guatemala 30.85
#
# Mexico 28.1

# %%
''' make weight matrix for all regions '''
for c in iata:
    for n in neighbors[c]:
        #print(c,n)
        weight[c][n]=get_weight(c,n)
# Out:
# Afghanistan Monaco
# steps 0.5
# Afghanistan Cuba
# steps 0.5
# Albania Monaco
# steps 0.5
# Albania Cuba
# steps 0.5
# Algeria Monaco
# steps 0.5
# Algeria Cuba
# steps 0.5
# Angola Monaco
# steps 0.5
# Angola Belarus
# steps 0.5
# Angola Cuba
# steps 0.5
# Antigua and Barbuda Cuba
# steps 0.5
# Antigua and Barbuda Monaco
# steps 0.5
# Argentina Cuba
# steps 0.5
# Argentina Monaco
# steps 0.5
# Armenia Monaco
# steps 0.5
# Armenia Barbados
# steps 0.5
# Armenia Cuba
# steps 0.5
# Australia Syria
# steps 0.5
# Australia Monaco
# steps 0.5
# Australia Barbados
# steps 0.5
# Australia Cuba
# steps 0.5
# Austria Monaco
# steps 0.5
# Austria Barbados
# steps 0.5
# Austria Cuba
# steps 0.5
# Azerbaijan Belarus
# steps 0.5
# Azerbaijan Monaco
# steps 0.5
# Azerbaijan Cuba
# steps 0.5
# Bahamas Cuba
# steps 1.5
# Bahamas Monaco
# steps 0.5
# Bahamas Azerbaijan
# steps 0.5
# Bahrain Monaco
# steps 0.5
# Bahrain Cuba
# steps 0.5
# Bangladesh Monaco
# steps 0.5
# Bangladesh Barbados
# steps 0.5
# Bangladesh Cuba
# steps 0.5
# Barbados Cuba
# steps 0.5
# Barbados Monaco
# steps 0.5
# Barbados Bangladesh
# steps 0.5
# Belarus Monaco
# steps 0.5
# Belarus Bahamas
# steps 0.5
# Belarus Cuba
# steps 1.0
# Belgium Monaco
# steps 0.5
# Belgium Cuba
# steps 0.5
# Belize Cuba
# steps 0.5
# Belize Monaco
# steps 0.5
# Belize Austria
# steps 0.5
# Bolivia Barbados
# steps 0.5
# Bolivia Cuba
# steps 0.5
# Bolivia Monaco
# steps 0.5
# Bolivia Syria
# steps 0.5
# Bosnia and Herzegovina Monaco
# steps 0.5
# Bosnia and Herzegovina Cuba
# steps 0.5
# Botswana Monaco
# steps 0.5
# Botswana Cuba
# steps 0.5
# Brazil Cuba
# steps 0.5
# Brazil Monaco
# steps 0.5
# Bulgaria Monaco
# steps 0.5
# Bulgaria Bahamas
# steps 0.5
# Bulgaria Cuba
# steps 1.0
# Burkina Faso Monaco
# steps 0.5
# Burkina Faso Bahamas
# steps 0.5
# Burkina Faso Cuba
# steps 1.0
# Cabo Verde Monaco
# steps 0.5
# Cabo Verde Bahamas
# steps 0.5
# Cabo Verde Cuba
# steps 1.0
# Cameroon Monaco
# steps 0.5
# Cameroon Cuba
# steps 0.5
# Canada Cuba
# steps 0.5
# Canada Monaco
# steps 0.5
# Central African Republic Monaco
# steps 0.5
# Central African Republic Cuba
# steps 0.5
# Chile Cuba
# steps 0.5
# Chile Monaco
# steps 0.5
# China Monaco
# steps 0.5
# China Cuba
# steps 0.5
# Colombia Cuba
# steps 0.5
# Colombia Monaco
# steps 0.5
# Comoros Azerbaijan
# steps 0.5
# Comoros Monaco
# steps 0.5
# Comoros Cuba
# steps 0.5
# Congo (Brazzaville) Monaco
# steps 0.5
# Congo (Brazzaville) Cuba
# steps 0.5
# Congo (Brazzaville) Australia
# steps 0.5
# Congo (Kinshasa) Monaco
# steps 0.5
# Congo (Kinshasa) Bahamas
# steps 0.5
# Congo (Kinshasa) Cuba
# steps 1.0
# Costa Rica Cuba
# steps 0.5
# Costa Rica Monaco
# steps 0.5
# Costa Rica Azerbaijan
# steps 0.5
# Cote d'Ivoire Monaco
# steps 0.5
# Cote d'Ivoire Cuba
# steps 0.5
# Croatia Monaco
# steps 0.5
# Croatia Azerbaijan
# steps 0.5
# Croatia Cuba
# steps 0.5
# Cuba Bahamas
# steps 1.5
# Cuba Jamaica
# steps 0.5
# Cuba Haiti
# steps 0.5
# Cuba Belize
# steps 0.5
# Cuba Honduras
# steps 0.5
# Cuba Dominican Republic
# steps 0.5
# Cuba Nicaragua
# steps 0.5
# Cuba El Salvador
# steps 0.5
# Cuba Guatemala
# steps 0.5
# Cuba Costa Rica
# steps 0.5
# Cuba Panama
# steps 0.5
# Cuba US
# steps 0.5
# Cuba Venezuela
# steps 0.5
# Cuba Colombia
# steps 0.5
# Cuba Mexico
# steps 0.5
# Cuba Antigua and Barbuda
# steps 0.5
# Cuba Saint Lucia
# steps 0.5
# Cuba Saint Vincent and the Grenadines
# steps 0.5
# Cuba Trinidad and Tobago
# steps 0.5
# Cuba Ecuador
# steps 0.5
# Cuba Barbados
# steps 0.5
# Cuba Canada
# steps 0.5
# Cuba Guyana
# steps 0.5
# Cuba Suriname
# steps 0.5
# Cuba Peru
# steps 0.5
# Cuba Bolivia
# steps 0.5
# Cuba Brazil
# steps 0.5
# Cuba Paraguay
# steps 0.5
# Cuba Chile
# steps 0.5
# Cuba Cabo Verde
# steps 0.5
# Cuba Argentina
# steps 0.5
# Cuba Uruguay
# steps 0.5
# Cuba Senegal
# steps 0.5
# Cuba Gambia
# steps 0.5
# Cuba Mauritania
# steps 0.5
# Cuba Guinea-Bissau
# steps 0.5
# Cuba Guinea
# steps 0.5
# Cuba Iceland
# steps 0.5
# Cuba Mali
# steps 0.5
# Cuba Portugal
# steps 0.5
# Cuba Morocco
# steps 0.5
# Cuba Cote d'Ivoire
# steps 0.5
# Cuba Spain
# steps 0.5
# Cuba Burkina Faso
# steps 0.5
# Cuba Ireland
# steps 0.5
# Cuba Ghana
# steps 0.5
# Cuba Togo
# steps 0.5
# Cuba Algeria
# steps 0.5
# Cuba United Kingdom
# steps 0.5
# Cuba France
# steps 0.5
# Cuba Nigeria
# steps 0.5
# Cuba Belgium
# steps 0.5
# Cuba Sao Tome and Principe
# steps 0.5
# Cuba Netherlands
# steps 0.5
# Cuba Monaco
# steps 1.0
# Cuba Luxembourg
# steps 0.5
# Cuba Equatorial Guinea
# steps 0.5
# Cuba Switzerland
# steps 0.5
# Cuba Tunisia
# steps 0.5
# Cuba Gabon
# steps 0.5
# Cuba Cameroon
# steps 0.5
# Cuba Libya
# steps 0.5
# Cuba Italy
# steps 0.5
# Cuba Malta
# steps 0.5
# Cuba Slovenia
# steps 0.5
# Cuba Germany
# steps 0.5
# Cuba Angola
# steps 0.5
# Cuba Denmark
# steps 0.5
# Cuba Czechia
# steps 0.5
# Cuba Norway
# steps 0.5
# Cuba Congo (Brazzaville)
# steps 0.5
# Cuba Croatia
# steps 0.5
# Cuba Congo (Kinshasa)
# steps 0.5
# Cuba Austria
# steps 0.5
# Cuba Central African Republic
# steps 0.5
# Cuba Slovakia
# steps 0.5
# Cuba Bosnia and Herzegovina
# steps 0.5
# Cuba Montenegro
# steps 0.5
# Cuba Albania
# steps 0.5
# Cuba Hungary
# steps 0.5
# Cuba Serbia
# steps 0.5
# Cuba Kosovo
# steps 0.5
# Cuba North Macedonia
# steps 0.5
# Cuba Sweden
# steps 0.5
# Cuba Greece
# steps 0.5
# Cuba Poland
# steps 0.5
# Cuba Bulgaria
# steps 0.5
# Cuba Namibia
# steps 0.5
# Cuba Romania
# steps 0.5
# Cuba Latvia
# steps 0.5
# Cuba Lithuania
# steps 0.5
# Cuba Estonia
# steps 0.5
# Cuba Finland
# steps 0.5
# Cuba Egypt
# steps 0.5
# Cuba Moldova
# steps 0.5
# Cuba Belarus
# steps 0.5
# Cuba Rwanda
# steps 0.5
# Cuba Sudan
# steps 0.5
# Cuba South Sudan
# steps 0.5
# Cuba Ukraine
# steps 0.5
# Cuba Cyprus
# steps 0.5
# Cuba Turkey
# steps 0.5
# Cuba Uganda
# steps 0.5
# Cuba Zambia
# steps 0.5
# Cuba Israel
# steps 0.5
# Cuba Botswana
# steps 0.5
# Cuba Lebanon
# steps 0.5
# Cuba Jordan
# steps 0.5
# Cuba Syria
# steps 0.5
# Cuba Zimbabwe
# steps 0.5
# Cuba South Africa
# steps 0.5
# Cuba Kenya
# steps 0.5
# Cuba Lesotho
# steps 0.5
# Cuba Malawi
# steps 0.5
# Cuba Ethiopia
# steps 0.5
# Cuba Eswatini
# steps 0.5
# Cuba Mozambique
# steps 0.5
# Cuba Russia
# steps 0.5
# Cuba Djibouti
# steps 0.5
# Cuba Iraq
# steps 0.5
# Cuba Armenia
# steps 0.5
# Cuba Georgia
# steps 0.5
# Cuba Saudi Arabia
# steps 0.5
# Cuba Somalia
# steps 0.5
# Cuba Comoros
# steps 0.5
# Cuba Kuwait
# steps 0.5
# Cuba Bahrain
# steps 0.5
# Cuba Azerbaijan
# steps 1.0
# Cuba Qatar
# steps 0.5
# Cuba Iran
# steps 0.5
# Cuba Madagascar
# steps 0.5
# Cuba United Arab Emirates
# steps 0.5
# Cuba Seychelles
# steps 0.5
# Cuba Oman
# steps 0.5
# Cuba Tajikistan
# steps 0.5
# Cuba Afghanistan
# steps 0.5
# Cuba Uzbekistan
# steps 0.5
# Cuba Pakistan
# steps 0.5
# Cuba Kazakhstan
# steps 0.5
# Cuba Maldives
# steps 0.5
# Cuba Kyrgyzstan
# steps 0.5
# Cuba India
# steps 0.5
# Cuba Sri Lanka
# steps 0.5
# Cuba Nepal
# steps 0.5
# Cuba Bangladesh
# steps 0.5
# Cuba Thailand
# steps 0.5
# Cuba Malaysia
# steps 0.5
# Cuba Singapore
# steps 0.5
# Cuba Mongolia
# steps 0.5
# Cuba Indonesia
# steps 0.5
# Cuba China
# steps 0.5
# Cuba Philippines
# steps 0.5
# Cuba Korea, South
# steps 0.5
# Cuba Japan
# steps 0.5
# Cuba Papua New Guinea
# steps 0.5
# Cuba Australia
# steps 0.5
# Cyprus Monaco
# steps 0.5
# Cyprus Cuba
# steps 0.5
# Czechia Austria
# steps 0.5
# Czechia Monaco
# steps 0.5
# Czechia Cuba
# steps 0.5
# Denmark Monaco
# steps 0.5
# Denmark Antigua and Barbuda
# steps 0.5
# Denmark Cuba
# steps 0.5
# Djibouti Monaco
# steps 0.5
# Djibouti Cuba
# steps 0.5
# Dominican Republic Cuba
# steps 0.5
# Dominican Republic Monaco
# steps 0.5
# Ecuador Cuba
# steps 0.5
# Ecuador Monaco
# steps 0.5
# Ecuador Azerbaijan
# steps 0.5
# Egypt Monaco
# steps 0.5
# Egypt Cuba
# steps 0.5
# El Salvador Cuba
# steps 0.5
# El Salvador Monaco
# steps 0.5
# Equatorial Guinea Monaco
# steps 0.5
# Equatorial Guinea Cuba
# steps 0.5
# Estonia Monaco
# steps 0.5
# Estonia Cuba
# steps 0.5
# Eswatini Monaco
# steps 0.5
# Eswatini Cuba
# steps 0.5
# Ethiopia Monaco
# steps 0.5
# Ethiopia Cuba
# steps 0.5
# Finland Monaco
# steps 0.5
# Finland Cuba
# steps 0.5
# France Monaco
# steps 0.5
# France Cuba
# steps 0.5
# Gabon Monaco
# steps 0.5
# Gabon Cuba
# steps 0.5
# Gambia Monaco
# steps 0.5
# Gambia Cuba
# steps 0.5
# Georgia Austria
# steps 0.5
# Georgia Monaco
# steps 0.5
# Georgia Cuba
# steps 0.5
# Germany Monaco
# steps 0.5
# Germany Cuba
# steps 0.5
# Ghana Monaco
# steps 0.5
# Ghana Bahamas
# steps 0.5
# Ghana Cuba
# steps 1.0
# Greece Monaco
# steps 0.5
# Greece Cuba
# steps 0.5
# Guatemala Cuba
# steps 1.0
# Guatemala Bahamas
# steps 0.5
# Guatemala Monaco
# steps 0.5
# Guinea Monaco
# steps 0.5
# Guinea Cuba
# steps 0.5
# Guinea Australia
# steps 0.5
# Guinea-Bissau Monaco
# steps 0.5
# Guinea-Bissau Cuba
# steps 0.5
# Guinea-Bissau Australia
# steps 0.5
# Guyana Cuba
# steps 0.5
# Guyana Monaco
# steps 0.5
# Guyana Azerbaijan
# steps 0.5
# Haiti Cuba
# steps 0.5
# Haiti Monaco
# steps 0.5
# Honduras Cuba
# steps 0.5
# Honduras Monaco
# steps 0.5
# Hungary Monaco
# steps 0.5
# Hungary Armenia
# steps 0.5
# Hungary Cuba
# steps 0.5
# Iceland Monaco
# steps 0.5
# Iceland Cuba
# steps 0.5
# India Azerbaijan
# steps 0.5
# India Monaco
# steps 0.5
# India Cuba
# steps 0.5
# Indonesia Monaco
# steps 0.5
# Indonesia Cuba
# steps 0.5
# Iran Monaco
# steps 0.5
# Iran Cuba
# steps 0.5
# Iraq Monaco
# steps 0.5
# Iraq Cuba
# steps 0.5
# Ireland Monaco
# steps 0.5
# Ireland Cuba
# steps 0.5
# Israel Monaco
# steps 0.5
# Israel Cuba
# steps 0.5
# Italy Monaco
# steps 0.5
# Italy Cuba
# steps 0.5
# Jamaica Cuba
# steps 0.5
# Jamaica Monaco
# steps 0.5
# Japan Monaco
# steps 0.5
# Japan Cuba
# steps 0.5
# Jordan Monaco
# steps 0.5
# Jordan Cuba
# steps 0.5
# Kazakhstan Azerbaijan
# steps 0.5
# Kazakhstan Monaco
# steps 0.5
# Kazakhstan Cuba
# steps 0.5
# Kenya Monaco
# steps 0.5
# Kenya Cuba
# steps 0.5
# Korea, South Monaco
# steps 0.5
# Korea, South Cuba
# steps 0.5
# Kosovo Monaco
# steps 0.5
# Kosovo Cuba
# steps 0.5
# Kuwait Monaco
# steps 0.5
# Kuwait Cuba
# steps 0.5
# Kyrgyzstan Monaco
# steps 0.5
# Kyrgyzstan Cuba
# steps 0.5
# Latvia Monaco
# steps 0.5
# Latvia Bahrain
# steps 0.5
# Latvia Cuba
# steps 0.5
# Lebanon Bahrain
# steps 0.5
# Lebanon Monaco
# steps 0.5
# Lebanon Cuba
# steps 0.5
# Lesotho Monaco
# steps 0.5
# Lesotho Cuba
# steps 0.5
# Libya Monaco
# steps 0.5
# Libya Cuba
# steps 0.5
# Lithuania Monaco
# steps 0.5
# Lithuania Cuba
# steps 0.5
# Luxembourg Monaco
# steps 0.5
# Luxembourg Barbados
# steps 0.5
# Luxembourg Cuba
# steps 0.5
# Madagascar Bangladesh
# steps 0.5
# Madagascar Monaco
# steps 0.5
# Madagascar Cuba
# steps 0.5
# Malawi Monaco
# steps 0.5
# Malawi Barbados
# steps 0.5
# Malawi Cuba
# steps 0.5
# Malaysia Bangladesh
# steps 0.5
# Malaysia Monaco
# steps 0.5
# Malaysia Cuba
# steps 0.5
# Maldives Bangladesh
# steps 0.5
# Maldives Monaco
# steps 0.5
# Maldives Cuba
# steps 0.5
# Mali Monaco
# steps 0.5
# Mali Cuba
# steps 0.5
# Malta Monaco
# steps 0.5
# Malta Barbados
# steps 0.5
# Malta Cuba
# steps 0.5
# Mauritania Monaco
# steps 0.5
# Mauritania Cuba
# steps 0.5
# Mexico Cuba
# steps 0.5
# Mexico Monaco
# steps 0.5
# Mexico Bangladesh
# steps 0.5
# Moldova Monaco
# steps 0.5
# Moldova Cuba
# steps 0.5
# Monaco Switzerland
# steps 1.0
# Monaco Italy
# steps 0.5
# Monaco Luxembourg
# steps 0.5
# Monaco France
# steps 0.5
# Monaco Tunisia
# steps 0.5
# Monaco Slovenia
# steps 0.5
# Monaco Belgium
# steps 0.5
# Monaco Algeria
# steps 0.5
# Monaco Croatia
# steps 0.5
# Monaco Netherlands
# steps 0.5
# Monaco Czechia
# steps 0.5
# Monaco Austria
# steps 0.5
# Monaco Malta
# steps 0.5
# Monaco Germany
# steps 0.5
# Monaco Slovakia
# steps 0.5
# Monaco United Kingdom
# steps 0.5
# Monaco Bosnia and Herzegovina
# steps 0.5
# Monaco Spain
# steps 0.5
# Monaco Montenegro
# steps 0.5
# Monaco Libya
# steps 0.5
# Monaco Hungary
# steps 0.5
# Monaco Albania
# steps 0.5
# Monaco Denmark
# steps 0.5
# Monaco Serbia
# steps 0.5
# Monaco Kosovo
# steps 0.5
# Monaco North Macedonia
# steps 0.5
# Monaco Poland
# steps 0.5
# Monaco Bulgaria
# steps 0.5
# Monaco Norway
# steps 0.5
# Monaco Ireland
# steps 0.5
# Monaco Morocco
# steps 0.5
# Monaco Portugal
# steps 0.5
# Monaco Greece
# steps 0.5
# Monaco Sweden
# steps 0.5
# Monaco Romania
# steps 0.5
# Monaco Lithuania
# steps 0.5
# Monaco Latvia
# steps 0.5
# Monaco Moldova
# steps 0.5
# Monaco Belarus
# steps 0.5
# Monaco Estonia
# steps 0.5
# Monaco Ukraine
# steps 0.5
# Monaco Finland
# steps 0.5
# Monaco Turkey
# steps 0.5
# Monaco Cyprus
# steps 0.5
# Monaco Egypt
# steps 0.5
# Monaco Lebanon
# steps 0.5
# Monaco Israel
# steps 0.5
# Monaco Syria
# steps 0.5
# Monaco Jordan
# steps 0.5
# Monaco Russia
# steps 0.5
# Monaco Burkina Faso
# steps 0.5
# Monaco Mauritania
# steps 0.5
# Monaco Nigeria
# steps 0.5
# Monaco Mali
# steps 0.5
# Monaco Iceland
# steps 0.5
# Monaco Armenia
# steps 0.5
# Monaco Georgia
# steps 0.5
# Monaco Sudan
# steps 0.5
# Monaco Togo
# steps 0.5
# Monaco Senegal
# steps 0.5
# Monaco Iraq
# steps 0.5
# Monaco Gambia
# steps 0.5
# Monaco Ghana
# steps 0.5
# Monaco Guinea-Bissau
# steps 0.5
# Monaco Cote d'Ivoire
# steps 0.5
# Monaco Equatorial Guinea
# steps 0.5
# Monaco Guinea
# steps 0.5
# Monaco Cameroon
# steps 0.5
# Monaco Central African Republic
# steps 0.5
# Monaco Cabo Verde
# steps 0.5
# Monaco Azerbaijan
# steps 0.5
# Monaco Kuwait
# steps 0.5
# Monaco Gabon
# steps 0.5
# Monaco Sao Tome and Principe
# steps 0.5
# Monaco Saudi Arabia
# steps 0.5
# Monaco Iran
# steps 0.5
# Monaco South Sudan
# steps 0.5
# Monaco Bahrain
# steps 0.5
# Monaco Ethiopia
# steps 0.5
# Monaco Qatar
# steps 0.5
# Monaco Djibouti
# steps 0.5
# Monaco Congo (Brazzaville)
# steps 0.5
# Monaco Congo (Kinshasa)
# steps 0.5
# Monaco Uganda
# steps 0.5
# Monaco United Arab Emirates
# steps 0.5
# Monaco Rwanda
# steps 0.5
# Monaco Angola
# steps 0.5
# Monaco Kenya
# steps 0.5
# Monaco Oman
# steps 0.5
# Monaco Somalia
# steps 0.5
# Monaco Tajikistan
# steps 0.5
# Monaco Uzbekistan
# steps 0.5
# Monaco Afghanistan
# steps 0.5
# Monaco Zambia
# steps 0.5
# Monaco Malawi
# steps 0.5
# Monaco Kazakhstan
# steps 0.5
# Monaco Comoros
# steps 0.5
# Monaco Zimbabwe
# steps 0.5
# Monaco Pakistan
# steps 0.5
# Monaco Namibia
# steps 0.5
# Monaco Kyrgyzstan
# steps 0.5
# Monaco Seychelles
# steps 0.5
# Monaco Botswana
# steps 0.5
# Monaco India
# steps 0.5
# Monaco South Africa
# steps 0.5
# Monaco Suriname
# steps 0.5
# Monaco Barbados
# steps 0.5
# Monaco Mozambique
# steps 0.5
# Monaco Antigua and Barbuda
# steps 0.5
# Monaco Eswatini
# steps 0.5
# Monaco Madagascar
# steps 0.5
# Monaco Saint Lucia
# steps 0.5
# Monaco Saint Vincent and the Grenadines
# steps 0.5
# Monaco Guyana
# steps 0.5
# Monaco Lesotho
# steps 0.5
# Monaco Trinidad and Tobago
# steps 0.5
# Monaco Maldives
# steps 0.5
# Monaco Nepal
# steps 0.5
# Monaco Dominican Republic
# steps 0.5
# Monaco Sri Lanka
# steps 0.5
# Monaco Brazil
# steps 0.5
# Monaco Venezuela
# steps 0.5
# Monaco Canada
# steps 0.5
# Monaco Haiti
# steps 0.5
# Monaco Bangladesh
# steps 0.5
# Monaco US
# steps 0.5
# Monaco Bahamas
# steps 0.5
# Monaco Jamaica
# steps 0.5
# Monaco Colombia
# steps 0.5
# Monaco Cuba
# steps 1.0
# Monaco Panama
# steps 0.5
# Monaco Paraguay
# steps 0.5
# Monaco Ecuador
# steps 0.5
# Monaco Bolivia
# steps 0.5
# Monaco Costa Rica
# steps 0.5
# Monaco Thailand
# steps 0.5
# Monaco Nicaragua
# steps 0.5
# Monaco Honduras
# steps 0.5
# Monaco Belize
# steps 0.5
# Monaco Mongolia
# steps 0.5
# Monaco Uruguay
# steps 0.5
# Monaco El Salvador
# steps 0.5
# Monaco Peru
# steps 0.5
# Monaco Guatemala
# steps 0.5
# Monaco Argentina
# steps 0.5
# Monaco Malaysia
# steps 0.5
# Monaco Singapore
# steps 0.5
# Monaco China
# steps 0.5
# Monaco Mexico
# steps 0.5
# Monaco Chile
# steps 0.5
# Monaco Indonesia
# steps 0.5
# Monaco Philippines
# steps 0.5
# Monaco Korea, South
# steps 0.5
# Monaco Japan
# steps 0.5
# Monaco Papua New Guinea
# steps 0.5
# Monaco Australia
# steps 0.5
# Mongolia Bahrain
# steps 0.5
# Mongolia Monaco
# steps 0.5
# Mongolia Cuba
# steps 0.5
# Montenegro Monaco
# steps 0.5
# Montenegro Bangladesh
# steps 0.5
# Montenegro Cuba
# steps 0.5
# Morocco Monaco
# steps 0.5
# Morocco Cuba
# steps 0.5
# Morocco Bangladesh
# steps 0.5
# Mozambique Bahrain
# steps 0.5
# Mozambique Monaco
# steps 0.5
# Mozambique Cuba
# steps 0.5
# Namibia Monaco
# steps 0.5
# Namibia Cuba
# steps 0.5
# Nepal Bangladesh
# steps 1.0
# Nepal Monaco
# steps 0.5
# Nepal Cuba
# steps 0.5
# Netherlands Monaco
# steps 0.5
# Netherlands Cuba
# steps 0.5
# Nicaragua Cuba
# steps 0.5
# Nicaragua Monaco
# steps 0.5
# Nicaragua Bahrain
# steps 0.5
# Nigeria Monaco
# steps 0.5
# Nigeria Bangladesh
# steps 0.5
# Nigeria Cuba
# steps 0.5
# North Macedonia Monaco
# steps 0.5
# North Macedonia Cuba
# steps 0.5
# Norway Monaco
# steps 0.5
# Norway Cuba
# steps 0.5
# Oman Monaco
# steps 0.5
# Oman Cuba
# steps 0.5
# Pakistan Bahrain
# steps 0.5
# Pakistan Monaco
# steps 0.5
# Pakistan Cuba
# steps 0.5
# Panama Cuba
# steps 0.5
# Panama Monaco
# steps 0.5
# Panama Bangladesh
# steps 0.5
# Papua New Guinea Monaco
# steps 0.5
# Papua New Guinea Cuba
# steps 0.5
# Paraguay Cuba
# steps 0.5
# Paraguay Monaco
# steps 0.5
# Peru Cuba
# steps 0.5
# Peru Monaco
# steps 0.5
# Philippines Monaco
# steps 0.5
# Philippines Barbados
# steps 0.5
# Philippines Cuba
# steps 0.5
# Poland Monaco
# steps 0.5
# Poland Cuba
# steps 0.5
# Portugal Monaco
# steps 0.5
# Portugal Cuba
# steps 0.5
# Qatar Monaco
# steps 0.5
# Qatar Cuba
# steps 0.5
# Romania Monaco
# steps 0.5
# Romania Armenia
# steps 0.5
# Romania Cuba
# steps 0.5
# Russia Monaco
# steps 0.5
# Russia Cuba
# steps 0.5
# Rwanda Bahrain
# steps 0.5
# Rwanda Monaco
# steps 0.5
# Rwanda Cuba
# steps 0.5
# Saint Lucia Cuba
# steps 0.5
# Saint Lucia Monaco
# steps 0.5
# Saint Vincent and the Grenadines Cuba
# steps 0.5
# Saint Vincent and the Grenadines Monaco
# steps 0.5
# Sao Tome and Principe Monaco
# steps 0.5
# Sao Tome and Principe Bahrain
# steps 0.5
# Sao Tome and Principe Cuba
# steps 0.5
# Saudi Arabia Monaco
# steps 0.5
# Saudi Arabia Cuba
# steps 0.5
# Senegal Monaco
# steps 0.5
# Senegal Cuba
# steps 0.5
# Serbia Monaco
# steps 0.5
# Serbia Bahrain
# steps 0.5
# Serbia Cuba
# steps 0.5
# Seychelles Monaco
# steps 0.5
# Seychelles Cuba
# steps 0.5
# Singapore Monaco
# steps 0.5
# Singapore Cuba
# steps 0.5
# Slovakia Monaco
# steps 0.5
# Slovakia Barbados
# steps 0.5
# Slovakia Cuba
# steps 0.5
# Slovenia Monaco
# steps 0.5
# Slovenia Barbados
# steps 0.5
# Slovenia Cuba
# steps 0.5
# Somalia Monaco
# steps 0.5
# Somalia Barbados
# steps 0.5
# Somalia Cuba
# steps 0.5
# South Africa Monaco
# steps 0.5
# South Africa Cuba
# steps 0.5
# South Sudan Monaco
# steps 0.5
# South Sudan Cuba
# steps 0.5
# Spain Monaco
# steps 0.5
# Spain Cuba
# steps 0.5
# Sri Lanka Monaco
# steps 0.5
# Sri Lanka Cuba
# steps 0.5
# Sudan Monaco
# steps 0.5
# Sudan Barbados
# steps 0.5
# Sudan Cuba
# steps 0.5
# Suriname Barbados
# steps 0.5
# Suriname Cuba
# steps 0.5
# Suriname Monaco
# steps 0.5
# Sweden Monaco
# steps 0.5
# Sweden Cuba
# steps 0.5
# Switzerland Monaco
# steps 1.0
# Switzerland Cuba
# steps 0.5
# Syria Monaco
# steps 0.5
# Syria Saint Vincent and the Grenadines
# steps 0.5
# Syria Bolivia
# steps 0.5
# Syria Cuba
# steps 0.5
# Tajikistan Bahrain
# steps 0.5
# Tajikistan Monaco
# steps 0.5
# Tajikistan Cuba
# steps 0.5
# Thailand Monaco
# steps 0.5
# Thailand Cuba
# steps 0.5
# Togo Monaco
# steps 0.5
# Togo Bahrain
# steps 0.5
# Togo Cuba
# steps 0.5
# Trinidad and Tobago Cuba
# steps 0.5
# Trinidad and Tobago Monaco
# steps 0.5
# Trinidad and Tobago Syria
# steps 0.5
# Tunisia Monaco
# steps 0.5
# Tunisia Cuba
# steps 0.5
# Turkey Monaco
# steps 0.5
# Turkey Cuba
# steps 0.5
# Uganda Bahrain
# steps 0.5
# Uganda Monaco
# steps 0.5
# Uganda Cuba
# steps 0.5
# Ukraine Monaco
# steps 0.5
# Ukraine Cuba
# steps 0.5
# United Arab Emirates Monaco
# steps 0.5
# United Arab Emirates Cuba
# steps 0.5
# United Kingdom Monaco
# steps 0.5
# United Kingdom Cuba
# steps 0.5
# Uruguay Cuba
# steps 0.5
# Uruguay Monaco
# steps 0.5
# Uruguay Bangladesh
# steps 0.5
# Uzbekistan Monaco
# steps 0.5
# Uzbekistan Cuba
# steps 0.5
# Venezuela Cuba
# steps 0.5
# Venezuela Monaco
# steps 0.5
# Venezuela Bahrain
# steps 0.5
# Zambia Monaco
# steps 0.5
# Zambia Bangladesh
# steps 0.5
# Zambia Cuba
# steps 0.5
# Zimbabwe Monaco
# steps 0.5
# Zimbabwe Cuba
# steps 0.5
# US Cuba
# steps 0.5
# US Monaco
# steps 0.5

# %%
import copy

def normalize_weight(weight):
    ''' invert and normalize weight elements '''
    weight_I=copy.deepcopy(weight) #.copy()
    for i in weight_I:
        norm=0
        for j in weight_I[i]:
            if weight_I[i][j]==0:
                print(i,j)
                weight_I[i][j]=weight_I[j][i]
            weight_I[i][j]=1/weight_I[i][j]
            norm+=weight_I[i][j]
        for j in weight_I[i]:
            weight_I[i][j]=weight_I[i][j]/norm
    return weight_I

# %%
weight_I=normalize_weight(weight)

# %%
#weight_I['Congo (Brazzaville)']

# %%
with open('weight_I_norm_apr29.pkl','wb') as f:
    pickle.dump(weight_I,f)

# %% [markdown]
# ## US demostic weights

# %%
distance=pd.read_csv("distance_us_states.csv")

# %%
states=list(distance['from'].unique())

# %%
states=list(distance['to'].unique())
states.append('Wyoming')
for i in range(len(states)):
    states[i]='US.'+states[i]

# %%
weight_D={s:{} for s in states}

ns=len(states)
for i in range(ns):
    for j in range(i):
        o=states[i]
        d=states[j]
        weight_D[d][o]=distance[(distance['from']==o[3:])&(distance['to']==d[3:])].distance.item()
        weight_D[o][d]=weight_D[d][o]

# %%
weight_D=normalize_weight(weight_D)

# %%
weight_D['US.Maryland']
# Out:
# {'US.Alabama': 0.009401699618191513,
#  'US.Alaska': 0.0023461577603785776,
#  'US.Arizona': 0.0033229102627923405,
#  'US.Arkansas': 0.007298282755628265,
#  'US.California': 0.00278331432327533,
#  'US.Colorado': 0.00443768066507311,
#  'US.Connecticut': 0.023837781000467618,
#  'US.Delaware': 0.11583034729384235,
#  'US.District of Columbia': 0.2602699078513038,
#  'US.Florida': 0.009093764304338326,
#  'US.Georgia': 0.01181963004716242,
#  'US.Hawaii': 0.0013784337617210728,
#  'US.Idaho': 0.0032358070577400925,
#  'US.Illinois': 0.009538103846779293,
#  'US.Indiana': 0.01303113621344056,
#  'US.Iowa': 0.007316428117815291,
#  'US.Kansas': 0.006486647994841765,
#  'US.Kentucky': 0.014790317250224297,
#  'US.Louisiana': 0.006573524130535371,
#  'US.Maine': 0.013162678946440937,
#  'US.Massachusetts': 0.017986133838203282,
#  'US.Michigan': 0.013549150599220768,
#  'US.Minnesota': 0.007099353070162776,
#  'US.Mississippi': 0.007487103535400506,
#  'US.Missouri': 0.007959782782702195,
#  'US.Montana': 0.003602286013706425,
#  'US.Nebraska': 0.006194235370719424,
#  'US.Nevada': 0.002914011909925753,
#  'US.New Hampshire': 0.01706029459244616,
#  'US.New Jersey': 0.050521214373273685,
#  'US.New Mexico': 0.004113736007736937,
#  'US.New York': 0.023507074365254996,
#  'US.North Carolina': 0.026753274968194237,
#  'US.North Dakota': 0.005015923498963101,
#  'US.Ohio': 0.018951281793042597,
#  'US.Oklahoma': 0.005679020536974525,
#  'US.Oregon': 0.0027998451837137643,
#  'US.Pennsylvania': 0.07458142066831062,
#  'US.Rhode Island': 0.020047108283032616,
#  'US.South Carolina': 0.015728245967150004,
#  'US.South Dakota': 0.0052380785849589105,
#  'US.Tennessee': 0.011282108979919325,
#  'US.Texas': 0.004982903656994242,
#  'US.Utah': 0.0035841325382370507,
#  'US.Vermont': 0.016124772765836987,
#  'US.Virginia': 0.06069756183308591,
#  'US.Washington': 0.0028224669201153273,
#  'US.West Virginia': 0.024088558538678875,
#  'US.Wisconsin': 0.009199813687103951,
#  'US.Wyoming': 0.004474551934942846}

# %%
with open('weight_D_norm_apr29.pkl','wb') as f:
    pickle.dump(weight_D,f)
